# %% [markdown]
# <a href="https://colab.research.google.com/github/SHADAMAKINIKHITHA/Myfirstproject/blob/master/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
p=np.array([[1,0],[0,1]])
q=np.array([[1,2],[3,4]])
pq=np.outer(p,q)
print(pq)
# Out:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %%
from numpy import linalg as l
n=np.array([[1,2],[3,4]])
print("orginal matrix:")
print(n)
print("conditional number of a is:")
print(l.cond(n))
# Out:
# orginal matrix:
# [[1 2]
#  [3 4]]
# conditional number of a is:
# 14.933034373659268

# %%
a=np.array([[1,5,2],[5,2,7],[8,3,9]])
sum=0
for i in range(0,3):
  for j in range(3):
    if i==j:
      sum=sum+a[i][j]
print(sum)
# Out:
# 12

# %%
import pandas as pd
import numpy as np
import matplotlib as mtp
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")

# %%
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")
ds
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 2           0         9        55  ...              2500             164         0
# 3           0         8        55  ...              3000             165         1
# 4           1         1        55  ...              3000             165         0
# ..        ...       ...       ...  ...               ...             ...       ...
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# ...

# %%
ds.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
null_columns=ds.columns[ds.isnull().any()]
print(ds[ds.isnull().any(axis=1)][null_columns].head())
# Out:
#     weight  stand_by_time  ...  video_resolution  primary_camera_resolution
# 10   169.0            NaN  ...             720.0                        8.0
# 62   170.0            NaN  ...            1080.0                       13.0
# 77   157.0          620.0  ...            1080.0                       20.0
# 83   142.6          504.0  ...               NaN                       21.2
# 85   176.0          200.0  ...             216.0                       16.0
#
# [5 rows x 7 columns]

# %%
ds=ds.apply(lambda x:x.fillna(x.mean()))
ds.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
null_columns=ds.columns[ds.isnull().any()]
print(null_columns)
print(ds[ds.isnull().any(axis=1)][null_columns].head())
# Out:
# Index([], dtype='object')
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as mtp
#import plotly.express  as px
ds=pd.read_csv("mobile_cleaned-1549119762886_-452616671.csv")

# %%
col=[x for x in ds.columns]
print(col)
for i in col:
  g1=ds.price
  mtp.plot(ds[i],g1)
# Out:
# ['sim_type', 'aperture', 'gpu_rank', 'weight', 'stand_by_time', 'processor_frequency', 'thickness', 'flash_type', 'front_camera_resolution', 'auto_focus', 'screen_size', 'frames_per_second', 'FM', 'no_of_reviews_in_gsmarena_in_week', 'os', 'phone_height', 'screen_protection', 'sim_size', 'price', 'talk_time', 'video_resolution', 'display_resolution', 'removable_battery', 'display_type', 'primary_camera_resolution', 'battery_type', 'ram_memory', 'internal_memory', 'brand_rank', 'no_of_cores', 'micro_sd_slot', 'screen_pixel_density', 'water_proof_rate', 'phone_width', 'expandable_memory', 'version', 'usb_type', 'battery_capacity', 'processor_rank', 'is_liked']
